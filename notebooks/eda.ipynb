# %%
# Out:
# Index(['Name', 'Age'], dtype='object')
# ['Name', 'Age']

# %%
import pandas as pd

# 1. Load the CSV
df = pd.read_csv("../data/raw/Posts_nature_org_18_Apr_2024_17_Apr_2025_7883.csv", sep=';')

# 2. Show available column names for inspection
print("Columns in the original file:")
print(df.columns.tolist())

# 3. Define the exact columns you want to keep
columns_to_keep = [
    "Caption",
    "Image Link",
    "Eng. Rate by Followers",
    "Date",
    "Type"
]

# 4. Clean column names (strip whitespace, fix misnamed headers)
df.columns = df.columns.str.strip()

# 5. Retain only the selected columns
df_cleaned = df[columns_to_keep]

# 6. Save to a cleaned file
df_cleaned.to_csv("../data/cleaned/Posts_nature_org_CLEANED.csv", index=False)

print("✅ File cleaned and saved.")
df_cleaned.head()
# Out:
# Columns in the original file:
# ['Profile', 'Permalink', 'Caption', 'Type', 'Date', 'Image Link', 'Engagement', 'Eng. Rate by Followers', 'Comments', 'Likes', 'Estimated Reach', 'Estimated Impressions']
# ✅ File cleaned and saved.
#                                              Caption  \
# 0  When we use our voices we can help preserve oc...
# 1  Its not every day you see an octopus hitching ...
# 2  What dives deeper than a submarine swims acros...
# 3  As you finalize your New Year’s resolutions vi...
# 4  Happy Earth Day!! 🌎🌱🌻🌿Today we are filled with...
#
#                                           Image Link  Eng. Rate by Followers  \
# 0  https://imgs.socialinsider.io/instagram/2024/1...                 0.74318
# 1  https://imgs.socialinsider.io/instagram/2024/1...                 0.66807
# 2  https://imgs.socialinsider.io/instagram/2024/0...                 0.65127
# 3  https://imgs.socialinsider.io/instagram/2025/0...                 0.64015
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style = "darkgrid")
df = pd.read_csv("../data/processed/Posts_carbonbrief_18_Apr_2024_17_Apr_2025_2db6 6_CLEANED.csv")

print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (118, 6)
#                                              Caption  \
# 0  In 2024 coal-power output in the US fell to it...
# 1  The UK s greenhouse gas emissions fell by 3.6%...
# 2  The Climate Change Committee (CCC) says reduci...
# 3  A record surge of clean energy kept China s CO...
# 4  This year is now virtually certain to beat 202...
#
#                                           Image Link  Eng. Rate by Followers  \
# 0  https://imgs.socialinsider.io/instagram/2025/0...                 7.34035
# 1  https://imgs.socialinsider.io/instagram/2025/0...                 6.59921
# 2  https://imgs.socialinsider.io/instagram/2025/0...                 4.86311
# 3  https://imgs.socialinsider.io/instagram/2025/0...                 4.10505
# 4  https://imgs.socialinsider.io/instagram/2024/1...                 3.07255
#
#                   Date            Type  \
# 0  2025-01-10 17:36:00  CAROUSEL_ALBUM
# 1  2025-03-13 17:26:00  CAROUSEL_ALBUM
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting style
sns.set(style="whitegrid")

# ----- 1. Post Type Distribution -----
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Type', order=df['Type'].value_counts().index, palette='magma')
plt.title("Distribution of Post Types")
plt.xlabel("Post Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# ----- 2. Caption Lengths -----
df['Caption Length'] = df['Caption'].apply(lambda x: len(str(x).split()))

plt.figure(figsize=(8, 5))
sns.histplot(df['Caption Length'], bins=30, kde=True, color="teal")
plt.title("Caption Length Distribution")
plt.xlabel("Number of Words in Caption")
plt.ylabel("Number of Posts")
plt.tight_layout()
plt.show()

# ----- 3. Engagement Rate Distribution -----
plt.figure(figsize=(8, 5))
sns.histplot(df['Eng. Rate by Followers'], bins=30, kde=True, color="purple")
plt.title("Engagement Rate by Followers Distribution")
plt.xlabel("Engagement Rate")
plt.ylabel("Number of Posts")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/bh/hm2q8sbn53vbkzw61rn0r6xm0000gn/T/ipykernel_85414/505294376.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Type', order=df['Type'].value_counts().index, palette='magma')

# %%
# Show summary statistics
print(df['Eng. Rate by Followers'].describe())
# Out:
# count    118.000000
# mean      12.651450
# std       78.206562
# min        0.084600
# 25%        0.383225
# 50%        0.619250
# 75%        1.177585
# max      714.000000
# Name: Eng. Rate by Followers, dtype: float64

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("../data/final_processed/Posts_carbonbrief_18_Apr_2024_17_Apr_2025_2db6 6_CLEANED.csv")

print("Dataset shape:", df.shape)
df.head()


# Set plotting style
sns.set(style="whitegrid")

# ----- 1. Post Type Distribution -----
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Type', order=df['Type'].value_counts().index, palette='magma')
plt.title("Distribution of Post Types")
plt.xlabel("Post Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# ----- 2. Caption Lengths -----
df['Caption Length'] = df['Caption'].apply(lambda x: len(str(x).split()))

plt.figure(figsize=(8, 5))
sns.histplot(df['Caption Length'], bins=30, kde=True, color="teal")
plt.title("Caption Length Distribution")
plt.xlabel("Number of Words in Caption")
plt.ylabel("Number of Posts")
plt.tight_layout()
plt.show()

# ----- 3. Engagement Rate Distribution -----
plt.figure(figsize=(8, 5))
sns.histplot(df['Eng. Rate by Followers'], bins=30, kde=True, color="purple")
plt.title("Engagement Rate by Followers Distribution")
plt.xlabel("Engagement Rate")
plt.ylabel("Number of Posts")
plt.tight_layout()
plt.show()
# Out:
# Dataset shape: (115, 6)
# /var/folders/bh/hm2q8sbn53vbkzw61rn0r6xm0000gn/T/ipykernel_85414/798828971.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Type', order=df['Type'].value_counts().index, palette='magma')
