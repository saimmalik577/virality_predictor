# %%
import pandas as pd

df = pd.read_csv("../data/raw/Posts_nature_org_18_Apr_2024_17_Apr_2025_7883.csv", sep=';')

df.head()

type_counts = df['Type'].value_counts()
type_counts

df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Profile                 272 non-null    object
#  1   Permalink               272 non-null    object
#  2   Caption                 272 non-null    object
#  3   Type                    272 non-null    object
#  4   Date                    272 non-null    object
#  5   Image Link              272 non-null    object
#  6   Engagement              272 non-null    int64
#  7   Eng. Rate by Followers  272 non-null    float64
#  8   Comments                272 non-null    int64
#  9   Likes                   272 non-null    int64
#  10  Estimated Reach         272 non-null    int64
#  11  Estimated Impressions   272 non-null    int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 25.6+ KB
#         Engagement  Eng. Rate by Followers    Comments        Likes  \
# count   272.000000              272.000000  272.000000   272.000000
# mean   1806.047794                0.844565   14.558824  1791.488971
# std    1228.700853                7.696848   18.990681  1221.824031
# min     210.000000                0.022180    0.000000   207.000000
# 25%     900.000000                0.095845    6.000000   882.500000
# 50%    1521.500000                0.161735   11.000000  1503.500000
# 75%    2268.750000                0.241733   18.000000  2250.750000
# max    7035.000000              103.000000  256.000000  6972.000000
#
#        Estimated Reach  Estimated Impressions
# count       272.000000             272.000000
# mean      35078.654412           38586.488971
# std       18115.405255           19926.945447
# min        5338.000000            5872.000000
# 25%       20754.000000           22829.750000
# 50%       32979.500000           36278.000000
# 75%       46273.250000           50900.250000
# max       93829.000000          103211.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style="dark")

# Plot
plt.figure(figsize=(8, 5))
sns.barplot(x=type_counts.index, y=type_counts.values, palette="viridis")
plt.title("Post Type Distribution")
plt.xlabel("Post Type")
plt.ylabel("Count")
plt.show()
# Out:
# /var/folders/bh/hm2q8sbn53vbkzw61rn0r6xm0000gn/T/ipykernel_82218/6391155.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=type_counts.index, y=type_counts.values, palette="viridis")
